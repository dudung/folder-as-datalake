# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "../../data/org/scatcs/"
df = pd.read_csv(path + "1110012390.csv", header=0, sep=',')
print(df)
# Out:
#      lambda           csa
# 0       300  4.094700e-14
# 1       302  4.105950e-14
# 2       304  4.118790e-14
# 3       306  4.133140e-14
# 4       308  4.149150e-14
# ..      ...           ...
# 246     792  1.284290e-14
# 247     794  1.267290e-14
# 248     796  1.250570e-14
# 249     798  1.234110e-14
# 250     800  1.217910e-14
#
# [251 rows x 2 columns]

# %%
plt.plot(df['lambda'], df['csa'])
